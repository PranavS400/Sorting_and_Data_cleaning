# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline
import matplotlib
matplotlib.rcParams['figure.figsize']=(20,10)

# %%
df=pd.read_excel('To_Sort.xlsx')
df.head()
# Out:
#              Domain                                   Location on Site  \
# 0  1800contacts.com                          workshop.1800contacts.com
# 1        babbel.com  pt.business.babbel.com;de.business.babbel.com;...
# 2      babylist.com  checkout.babylist.com;staging-checkout.babylis...
# 3    ballislife.com  shop.ballislife.com;ballislife.com/*;publisher...
# 4     barnfinds.com                                 shop.barnfinds.com
#
#   Tech Spend USD           Company                 Vertical Quantcast  \
# 0         $10000    1-800 Contacts  Business And Industrial      8185
# 1          $2000  Lesson Nine GmbH                Education    205860
# 2          $2000      Babylist Inc     Family And Parenting    770604
# 3          $2000               NaN  Business And Industrial    568364
# 4           $500               NaN  Automotive And Vehicles    190038
#
#             Alexa Majestic        Umbrella  \
# 0           21584    85614           32346
# ...

# %%
data = []
df1 = pd.DataFrame(data)
df1.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df1['Company Name']=df['Company']
df1.head()
# Out:
#        Company Name
# 0    1-800 Contacts
# 1  Lesson Nine GmbH
# 2      Babylist Inc
# 3               NaN
# 4               NaN

# %%
df['People']=df['People'].fillna("")

# %%
def sqft_conversion(x):
    splitting=x.split(' ')
    if len(splitting)==2:
        return splitting[0]
    try:
        return splitting[0]
    except:
        return None

# %%
def second_name(x):
    splitting=x.split(' ')
    if len(splitting)==2:
        return splitting[1]
    try:
        return splitting[1]
    except:
        return None

# %%
def Main_name(x):
    splitting=x.split('-')
    if len(splitting)>2:
        return splitting[0]
    try:
        return x
    except:
        return None

# %%
def Designation(x):
    splitting=x.split('-')
    if len(splitting)>2:
        return splitting[1]
    try:
        return splitting[1]
    except:
        return None

# %%
df['Name']=df['People'].apply(Main_name)
df1['First Name'] = df['Name'].apply(sqft_conversion)
df1['Last Name'] = df['Name'].apply(second_name)
df1['Designation']=df['People'].apply(Designation)

# %%
df.head()
# Out:
#              Domain                                   Location on Site  \
# 0  1800contacts.com                          workshop.1800contacts.com
# 1        babbel.com  pt.business.babbel.com;de.business.babbel.com;...
# 2      babylist.com  checkout.babylist.com;staging-checkout.babylis...
# 3    ballislife.com  shop.ballislife.com;ballislife.com/*;publisher...
# 4     barnfinds.com                                 shop.barnfinds.com
#
#   Tech Spend USD           Company                 Vertical Quantcast  \
# 0         $10000    1-800 Contacts  Business And Industrial      8185
# 1          $2000  Lesson Nine GmbH                Education    205860
# 2          $2000      Babylist Inc     Family And Parenting    770604
# 3          $2000               NaN  Business And Industrial    568364
# 4           $500               NaN  Automotive And Vehicles    190038
#
#             Alexa Majestic        Umbrella  \
# 0           21584    85614           32346
# ...

# %%
df1.head()
# Out:
#        Company Name First Name Last Name Designation
# 0    1-800 Contacts                 None        None
# 1  Lesson Nine GmbH        N/A             Director
# 2      Babylist Inc      Tonya     Baker   Designer
# 3               NaN      Randy    Watson    Manager
# 4               NaN                 None        None

# %%
def fillna_company_name(x):
    splitting=x.split('.')
    if len(splitting)>=2:
        return splitting[0]
    try:
        return splitting[0]
    except:
        return None

# %%
df['company nan value']=df['Domain'].apply(fillna_company_name)
df['Company']=df['Company'].fillna(df['company nan value'])

# %%
df.head()
# Out:
#              Domain                                   Location on Site  \
# 0  1800contacts.com                          workshop.1800contacts.com
# 1        babbel.com  pt.business.babbel.com;de.business.babbel.com;...
# 2      babylist.com  checkout.babylist.com;staging-checkout.babylis...
# 3    ballislife.com  shop.ballislife.com;ballislife.com/*;publisher...
# 4     barnfinds.com                                 shop.barnfinds.com
#
#   Tech Spend USD           Company                 Vertical Quantcast  \
# 0         $10000    1-800 Contacts  Business And Industrial      8185
# 1          $2000  Lesson Nine GmbH                Education    205860
# 2          $2000      Babylist Inc     Family And Parenting    770604
# 3          $2000        ballislife  Business And Industrial    568364
# 4           $500         barnfinds  Automotive And Vehicles    190038
#
#             Alexa Majestic        Umbrella  \
# 0           21584    85614           32346
# ...

# %%
df1['Company Name']=df1['Company Name'].fillna(df['company nan value'])
df1.head()
# Out:
#        Company Name First Name Last Name Designation
# 0    1-800 Contacts                 None        None
# 1  Lesson Nine GmbH        N/A             Director
# 2      Babylist Inc      Tonya     Baker   Designer
# 3        ballislife      Randy    Watson    Manager
# 4         barnfinds                 None        None

# %%
df1['Email']=df['Emails']
df1.head()
# Out:
#        Company Name First Name Last Name Designation  \
# 0    1-800 Contacts                 None        None
# 1  Lesson Nine GmbH        N/A             Director
# 2      Babylist Inc      Tonya     Baker   Designer
# 3        ballislife      Randy    Watson    Manager
# 4         barnfinds                 None        None
#
#                                                Email
# 0  customercare@1800contacts.com;info@1800contact...
# 1                                 support@babbel.com
# 2  pics@babylist.com;natalie@babylist.com;hello@b...
# 3                              ronnie@ballislife.com
# 4                                 mail@barnfinds.com

# %%
df1['Tech spend']=df['Tech Spend USD']

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company Name  199 non-null    object
#  1   First Name    199 non-null    object
#  2   Last Name     147 non-null    object
#  3   Designation   147 non-null    object
#  4   Email         169 non-null    object
#  5   Tech spend    199 non-null    object
# dtypes: object(6)
# memory usage: 9.5+ KB

# %%
def Price_conversion(x):
    splitting=x.split('$')
    if len(splitting)>=2:
        return int(splitting[1])
    try:
        return int(splitting[1])
    except:
        return None

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company Name  199 non-null    object
#  1   First Name    199 non-null    object
#  2   Last Name     147 non-null    object
#  3   Designation   147 non-null    object
#  4   Email         169 non-null    object
#  5   Tech spend    199 non-null    object
# dtypes: object(6)
# memory usage: 9.5+ KB

# %%
df1.head()
# Out:
#        Company Name First Name Last Name Designation  \
# 0    1-800 Contacts                 None        None
# 1  Lesson Nine GmbH        N/A             Director
# 2      Babylist Inc      Tonya     Baker   Designer
# 3        ballislife      Randy    Watson    Manager
# 4         barnfinds                 None        None
#
#                                                Email Tech spend
# 0  customercare@1800contacts.com;info@1800contact...     $10000
# 1                                 support@babbel.com      $2000
# 2  pics@babylist.com;natalie@babylist.com;hello@b...      $2000
# 3                              ronnie@ballislife.com      $2000
# 4                                 mail@barnfinds.com       $500

# %%
df1['VERTICAL']=df['Vertical']
df1.head()
# Out:
#        Company Name First Name Last Name Designation  \
# 0    1-800 Contacts                 None        None
# 1  Lesson Nine GmbH        N/A             Director
# 2      Babylist Inc      Tonya     Baker   Designer
# 3        ballislife      Randy    Watson    Manager
# 4         barnfinds                 None        None
#
#                                                Email Tech spend  \
# 0  customercare@1800contacts.com;info@1800contact...     $10000
# 1                                 support@babbel.com      $2000
# 2  pics@babylist.com;natalie@babylist.com;hello@b...      $2000
# 3                              ronnie@ballislife.com      $2000
# 4                                 mail@barnfinds.com       $500
#
#                   VERTICAL
# 0  Business And Industrial
# 1                Education
# 2     Family And Parenting
# 3  Business And Industrial
# 4  Automotive And Vehicles

# %%
df1.head()
# Out:
#        Company Name First Name Last Name Designation  \
# 0    1-800 Contacts                 None        None
# 1  Lesson Nine GmbH        N/A             Director
# 2      Babylist Inc      Tonya     Baker   Designer
# 3        ballislife      Randy    Watson    Manager
# 4         barnfinds                 None        None
#
#                                                Email Tech spend  \
# 0  customercare@1800contacts.com;info@1800contact...     $10000
# 1                                 support@babbel.com      $2000
# 2  pics@babylist.com;natalie@babylist.com;hello@b...      $2000
# 3                              ronnie@ballislife.com      $2000
# 4                                 mail@barnfinds.com       $500
#
#                   VERTICAL
# 0  Business And Industrial
# 1                Education
# 2     Family And Parenting
# 3  Business And Industrial
# 4  Automotive And Vehicles

# %%
g=df1.groupby('Company Name')

# %%
g

# %%
def Price_conversion(x):
    splitting=x.split('$')
    if len(splitting)>=2:
        return int(splitting[1])
    try:
        return int(splitting[1])
    except:
        return None

# %%
df2=df1.copy()
df2['Tech Sppp']=df1['Tech spend'].apply(Price_conversion)
df2.head()
# Out:
#        Company Name First Name Last Name Designation  \
# 0    1-800 Contacts                 None        None
# 1  Lesson Nine GmbH        N/A             Director
# 2      Babylist Inc      Tonya     Baker   Designer
# 3        ballislife      Randy    Watson    Manager
# 4         barnfinds                 None        None
#
#                                                Email Tech spend  \
# 0  customercare@1800contacts.com;info@1800contact...     $10000
# 1                                 support@babbel.com      $2000
# 2  pics@babylist.com;natalie@babylist.com;hello@b...      $2000
# 3                              ronnie@ballislife.com      $2000
# 4                                 mail@barnfinds.com       $500
#
#                   VERTICAL  Tech Sppp
# 0  Business And Industrial      10000
# 1                Education       2000
# 2     Family And Parenting       2000
# 3  Business And Industrial       2000
# 4  Automotive And Vehicles        500

# %%
df2.drop('Tech Sppp',axis='columns', inplace=True)

# %%
df2.head()
# Out:
#        Company Name First Name Last Name Designation  \
# 0    1-800 Contacts                 None        None
# 1  Lesson Nine GmbH        N/A             Director
# 2      Babylist Inc      Tonya     Baker   Designer
# 3        ballislife      Randy    Watson    Manager
# 4         barnfinds                 None        None
#
#                                                Email Tech spend  \
# 0  customercare@1800contacts.com;info@1800contact...     $10000
# 1                                 support@babbel.com      $2000
# 2  pics@babylist.com;natalie@babylist.com;hello@b...      $2000
# 3                              ronnie@ballislife.com      $2000
# 4                                 mail@barnfinds.com       $500
#
#                   VERTICAL
# 0  Business And Industrial
# 1                Education
# 2     Family And Parenting
# 3  Business And Industrial
# 4  Automotive And Vehicles

# %%
df2.to_excel(r'C:\Users\ASUS\Downloads\Sorted.xlsx', index = False)
